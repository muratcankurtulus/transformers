# %%
import typing
from pathlib import Path
from collections import defaultdict
import re

# %%
paths = [x for x in Path('/home/maskedpirate/repos/DATA/nlpdata/bookcorpus').glob('*.txt')]

# %%
class BPE:
    def __init__(self, vocab_size=50):
        self.vocab_size = vocab_size
        self.vocab = set() 
        self.split = list()


    @staticmethod 
    def __create_corpus(path: Path):
        '''Creates the first word corpus for BPE.

        Parameters:
            path[Path]: path to the txt file 
        '''
        with open(path, 'r') as f:
            file = f.read()
        return re.sub(r'[^\x00-\x7F]+', '', file).split(' ')


    def __split_and_initiate(self, wordcorpus: list):
        for word in wordcorpus:
            for char in word:
                self.split.append(char)
                self.vocab.add(char)
        
        
    def __count(self):
        '''Creates a defaultdict which shows frequency of 
        repeated elements.
        
        Parameters:
            placeholder 
        Returns:
            splits[defaultdict]: defaultdict of frequencies
        '''
        pairs = defaultdict(int)
        splint_len = len(self.split)
        for i in range(splint_len-1):
            pair = f'{self.split[i]}<sp>{self.split[i+1]}'
            pairs[pair] += 1
            if len(pairs) > 50:
                break
        return pairs


    def __add_to_vocab(self, pairs, max_freq):
        '''Adds given tokens to vocab'''
        for tup in pairs.items():
            if tup[1] == max_freq:
                self.vocab.add(tup[0].replace('<sp>', ''))
                
            
    def __merge(self, pair):
        f, s = pair.split('<sp>')
        ind = 0
        while ind < len(self.split) - 1:
            if self.split[ind] == f and self.split[ind+1] == s:
                self.split = self.split[:ind] + [f+s] + self.split[ind+2:]
            else:
                ind += 1
                    
    def __find_best(self):
        pairs = self.__count()
        max_freq = max(pairs.values())
        highest_freq_vals = [k for k, v in pairs.items() if v == max_freq]
        self.__add_to_vocab(pairs, max_freq)
        for item in highest_freq_vals:
            self.__merge(item)

 
    def train(self, path, vocab_size):
        corpus = self.__create_corpus(path)
        self.__split_and_initiate(corpus)
        while len(self.vocab) < vocab_size:
            self.__find_best()
            print(f'vocab: {self.vocab}')
            print(f'splits: {self.split}')

# %%
paths
# Out:
# [PosixPath('/home/maskedpirate/repos/DATA/nlpdata/bookcorpus/books_large_p1.txt'),
#  PosixPath('/home/maskedpirate/repos/DATA/nlpdata/bookcorpus/books_large_p2.txt')]

# %%
tokenizer = BPE()
tokenizer.train('./toy_data/example.txt', 200)
# Out:
# vocab: {'g', '3', '4', 'd', 'c', 'z', '0', 'j', 'b', '.', 'm', '-', 'er', '1', 'i', ':', '7', 'f', 'p', 't', 'k', 'o', 'y', 'a', 'h', 'n', ',', 'r', '9', 'e', '?', 'x', 'v', 's', '2', '\n', 'w', 'l', '8', 'q', 'u'}
# splits: ['t', 'h', 'e', 'h', 'a', 'l', 'f', '-', 'l', 'i', 'n', 'g', 'b', 'o', 'o', 'k', 'o', 'n', 'e', 'i', 'n', 't', 'h', 'e', 'f', 'a', 'l', 'l', 'o', 'f', 'i', 'g', 'n', 'e', 'er', 'i', 'a', 's', 'er', 'i', 'e', 's', 'k', 'a', 'y', 'l', 'e', 'e', 's', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'c', 'o', 'p', 'y', 'r', 'i', 'g', 'h', 't', '2', '0', '1', '3', 'k', 'a', 'y', 'l', 'e', 'e', 's', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'a', 'l', 'l', 'r', 'i', 'g', 'h', 't', 's', 'r', 'e', 's', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'c', 'o', 'u', 'r', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'o', 'n', 'e', 'v', 'er', 's', 't', 'o', 'p', 'f', 'i', 'g', 'h', 't', 'i', 'n', 'g', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'r', 'i', 'g', 'h', 't', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 't', 'h', 'a', 't', 'q', 'u', 'e', 's', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'l', 'i', 'n', 'g', 's', ',', 'n', 'e', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 't', 'h', 'e', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'h', 't', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'a', 's', 'm', 'a', 'l', 'l', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 't', 'h', 'e', 'k', 'i', 'n', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'o', 'n', 'e', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'u', 'r', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'r', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'a', 'y', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'i', 'n', 'g', 'w', 'i', 't', 'h', 'y', 'o', 'u', 'r', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'o', 'n', 'e', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'c', 'o', 'm', 'f', 'y', '.', '\n', 't', 'h', 'e', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 't', 'h', 'e', 'h', 'a', 'l', 'f', 'o', 'f', 'i', 't', '.', '\n', 'b', 'u', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'a', 'l', 'l', 'a', 'n', 'd', 's', 't', 'a', 'r', 'l', 'i', 'n', 'g', 's', 'i', 's', 'n', 'o', 't', 't', 'h', 'e', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 't', 'h', 'e', 'o', 'n', 'l', 'y', 'r', 'e', 'a', 's', 'o', 'n', 'w', 'h', 'y', 'n', 'o', 'o', 'n', 'e', 'k', 'n', 'o', 'w', 's', 't', 'h', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'a', 's', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 't', 'h', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 't', 'h', 'a', 't', 'w', 'a', 'y', '.', '\n', 'i', 'w', 'a', 'l', 'k', 'e', 'd', 'a', 'l', 'o', 'n', 'g', 't', 'h', 'e', 'e', 'm', 'p', 't', 'y', 'r', 'o', 'a', 'd', 'a', 'l', 'o', 'n', 'e', ',', 'o', 'c', 'c', 'a', 's', 'i', 'o', 'n', 'a', 'l', 'l', 'y', 'w', 'a', 'v', 'i', 'n', 'g', 't', 'o', 'p', 'a', 's', 's', 'i', 'n', 'g', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'e', 's', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'a', 's', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'd', 'er', ',', 'f', 'i', 'l', 'l', 'e', 'd', 'w', 'i', 't', 'h', 'm', 'y', 'w', 'r', 'i', 't', 'i', 'n', 'g', 'b', 'o', 'o', ' ...
# vocab: {'g', 'eri', '3', '4', 'd', 'c', 'in', 'z', 'al', '0', 'j', 'b', '.', 'm', '-', 'er', '1', 'i', ':', 'es', '7', 'f', 'p', 't', 'k', 'o', 'y', 'he', 'a', 'h', 'n', ',', 'r', '9', 'e', '?', 'x', 'v', 's', '2', '\n', 'w', 'l', '8', 'ne', 'q', 'th', 'u'}
# splits: ['th', 'e', 'h', 'al', 'f', '-', 'l', 'in', 'g', 'b', 'o', 'o', 'k', 'o', 'ne', 'in', 'th', 'e', 'f', 'al', 'l', 'o', 'f', 'i', 'g', 'ne', 'eri', 'a', 's', 'eri', 'es', 'k', 'a', 'y', 'l', 'e', 'es', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'c', 'o', 'p', 'y', 'r', 'i', 'g', 'h', 't', '2', '0', '1', '3', 'k', 'a', 'y', 'l', 'e', 'es', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'al', 'l', 'r', 'i', 'g', 'h', 't', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'c', 'o', 'u', 'r', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'o', 'ne', 'v', 'er', 's', 't', 'o', 'p', 'f', 'i', 'g', 'h', 't', 'in', 'g', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'r', 'i', 'g', 'h', 't', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'l', 'in', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'th', 'e', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'h', 't', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'a', 's', 'm', 'al', 'l', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'th', 'e', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'o', 'ne', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'u', 'r', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'r', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'a', 'y', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'in', 'g', 'w', 'i', 'th', 'y', 'o', 'u', 'r', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'o', 'ne', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'c', 'o', 'm', 'f', 'y', '.', '\n', 'th', 'e', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'th', 'e', 'h', 'al', 'f', 'o', 'f', 'i', 't', '.', '\n', 'b', 'u', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'al', 'l', 'a', 'n', 'd', 's', 't', 'a', 'r', 'l', 'in', 'g', 's', 'i', 's', 'n', 'o', 't', 'th', 'e', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'th', 'e', 'o', 'n', 'l', 'y', 'r', 'e', 'a', 's', 'o', 'n', 'w', 'h', 'y', 'n', 'o', 'o', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'a', 's', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'a', 'y', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'th', 'e', 'e', 'm', 'p', 't', 'y', 'r', 'o', 'a', 'd', 'al', 'o', 'ne', ',', 'o', 'c', 'c', 'a', 's', 'i', 'o', 'n', 'al', 'l', 'y', 'w', 'a', 'v', 'in', 'g', 't', 'o', 'p', 'a', 's', 's', 'in', 'g', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'a', 's', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'd', 'er', ',', 'f', 'i', 'l', 'l', 'e', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'in', 'g', 'b', 'o', 'o', 'k', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'es', 'o', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', ' ...
# vocab: {'g', 'eri', '3', '4', 'd', 'c', 'in', 'z', 'al', '0', 'j', 'b', '.', 'm', '-', 'er', 'ig', '1', 'i', ':', 'es', '7', 'f', 'p', 't', 'k', 'o', 'y', 'he', 'a', 'h', 'n', ',', 'r', '9', 'e', '?', 'x', 'v', 's', '2', '\n', 'w', 'l', '8', 'ne', 'q', 'th', 'u', 'the'}
# splits: ['the', 'h', 'al', 'f', '-', 'l', 'in', 'g', 'b', 'o', 'o', 'k', 'o', 'ne', 'in', 'the', 'f', 'al', 'l', 'o', 'f', 'ig', 'ne', 'eri', 'a', 's', 'eri', 'es', 'k', 'a', 'y', 'l', 'e', 'es', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'c', 'o', 'p', 'y', 'r', 'ig', 'h', 't', '2', '0', '1', '3', 'k', 'a', 'y', 'l', 'e', 'es', 'o', 'd', 'er', 'b', 'u', 'r', 'g', 'al', 'l', 'r', 'ig', 'h', 't', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'c', 'o', 'u', 'r', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'o', 'ne', 'v', 'er', 's', 't', 'o', 'p', 'f', 'ig', 'h', 't', 'in', 'g', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'r', 'ig', 'h', 't', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'l', 'in', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'h', 't', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'a', 's', 'm', 'al', 'l', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'o', 'ne', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'u', 'r', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'r', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'a', 'y', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'in', 'g', 'w', 'i', 'th', 'y', 'o', 'u', 'r', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'o', 'ne', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'c', 'o', 'm', 'f', 'y', '.', '\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'the', 'h', 'al', 'f', 'o', 'f', 'i', 't', '.', '\n', 'b', 'u', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'al', 'l', 'a', 'n', 'd', 's', 't', 'a', 'r', 'l', 'in', 'g', 's', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'the', 'o', 'n', 'l', 'y', 'r', 'e', 'a', 's', 'o', 'n', 'w', 'h', 'y', 'n', 'o', 'o', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'a', 's', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'a', 'y', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'y', 'r', 'o', 'a', 'd', 'al', 'o', 'ne', ',', 'o', 'c', 'c', 'a', 's', 'i', 'o', 'n', 'al', 'l', 'y', 'w', 'a', 'v', 'in', 'g', 't', 'o', 'p', 'a', 's', 's', 'in', 'g', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'a', 's', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'd', 'er', ',', 'f', 'i', 'l', 'l', 'e', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'in', 'g', 'b', 'o', 'o', 'k', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'es', 'o', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'in', 'g', 'm', ' ...
# vocab: {'gb', 'gc', 'z', 'hal', '0', 'oo', 'eria', 't', 'he', 'erb', 'h', ',', 'esk', 'ay', 's', 'seri', 'ok', 'q', 't2', 'u', '3', 'd', 'thef', 'py', 'inthe', 'm', 'co', '1', 'rig', 'es', 'bo', 'igne', 'op', 'ko', 'r', 'le', '2', 'alf', 'ht', 'eries', 'l', 'lo', 'th', 'yl', 'as', 'ka', 'c', 'ur', 'b', 'ing', 'er', 'bu', 'ig', '7', 'f', 'y', 'nein', 'a', 'n', 'fig', '9', 'e', '?', 'x', '\n', '8', 'ne', 'igh', 'all', 'od', 'neeri', '20', 'ees', 'the', 'g', 'eri', '4', 'in', 'f-', 'al', 'j', '.', 'theh', '-', 'of', 'fal', 'i', ':', 'lin', 'p', 'k', 'o', 'eso', 'one', 'rg', 'der', 'v', 'w', '-l', '01', 'yr'}
# splits: ['theh', 'alf', '-l', 'ing', 'bo', 'ok', 'one', 'inthe', 'fal', 'lo', 'fig', 'neeri', 'as', 'eries', 'ka', 'yl', 'ees', 'od', 'erb', 'ur', 'gc', 'op', 'yr', 'igh', 't2', '01', '3', 'ka', 'yl', 'ees', 'od', 'erb', 'ur', 'g', 'all', 'rig', 'ht', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'rig', 'ht', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.', '\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'theh', 'alf', 'of', 'i', 't', '.', '\n', 'bu', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ing', 'bo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.', '\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'e', 'd', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a',  ...
# vocab: {'gb', 'gc', 'z', 'hal', '0', 'oo', 'eria', 't', 'he', 'erb', 'h', ',', 'esk', 'ay', 's', 'seri', 'ok', 'q', 't2', 'u', '3', 'd', 'thef', 'py', 'inthe', 'oderb', 'm', 'co', '1', 'rig', 'es', 'bo', 'igne', 'op', 'ko', 'r', 'le', '2', 'alf', 'ht', 'eries', 'l', 'lo', 'th', 'yl', 'as', 'ka', 'kayl', 'c', 'ur', 'b', 'ing', 'er', 'bu', 'ig', '7', 'eesod', 'f', 'y', 'nein', 'a', 'n', 'fig', '9', 'e', 'ylees', '?', 'x', '\n', '8', 'ne', 'igh', 'all', 'od', 'neeri', '20', 'ees', 'the', 'g', 'eri', '4', 'in', 'f-', 'al', 'j', '.', 'theh', '-', 'of', 'fal', 'i', ':', 'lin', 'erbur', 'p', 'k', 'o', 'eso', 'one', 'rg', 'der', 'v', 'w', '-l', '01', 'yr'}
# splits: ['theh', 'alf', '-l', 'ing', 'bo', 'ok', 'one', 'inthe', 'fal', 'lo', 'fig', 'neeri', 'as', 'eries', 'kayl', 'eesod', 'erbur', 'gc', 'op', 'yr', 'igh', 't2', '01', '3', 'kayl', 'eesod', 'erbur', 'g', 'all', 'rig', 'ht', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'rig', 'ht', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.', '\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'theh', 'alf', 'of', 'i', 't', '.', '\n', 'bu', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ing', 'bo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.', '\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'e', 'd', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', ...
# vocab: {'gb', 'gc', 'z', 'hal', '0', 'oo', 'eria', 't', 'he', 'erb', 'h', ',', 'eesoderbur', 'esk', 'ay', 's', 'seri', 'ok', 'q', 't2', 'u', '3', 'd', 'thef', 'py', 'inthe', 'oderb', 'm', 'co', '1', 'rig', 'es', 'bo', 'igne', 'op', 'ko', 'r', 'le', '2', 'alf', 'ht', 'eries', 'l', 'lo', 'th', 'yl', 'as', 'ka', 'kayl', 'c', 'ur', 'b', 'ing', 'er', 'bu', 'ig', '7', 'eesod', 'f', 'y', 'nein', 'a', 'n', 'fig', '9', 'e', 'ylees', '?', 'x', '\n', '8', 'ne', 'igh', 'all', 'od', 'neeri', '20', 'ees', 'the', 'g', 'eri', '4', 'in', 'f-', 'al', 'j', '.', 'theh', '-', 'of', 'fal', 'i', ':', 'lin', 'erbur', 'p', 'k', 'o', 'eso', 'one', 'rg', 'der', 'v', 'kayleesod', 'w', '-l', '01', 'yr'}
# splits: ['theh', 'alf', '-l', 'ing', 'bo', 'ok', 'one', 'inthe', 'fal', 'lo', 'fig', 'neeri', 'as', 'eries', 'kayleesod', 'erbur', 'gc', 'op', 'yr', 'igh', 't2', '01', '3', 'kayleesod', 'erbur', 'g', 'all', 'rig', 'ht', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'rig', 'ht', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.', '\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'theh', 'alf', 'of', 'i', 't', '.', '\n', 'bu', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ing', 'bo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.', '\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'e', 'd', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', 'r', 'a ...
# vocab: {'gb', 'gc', 'z', 'hal', '0', 'oo', 'eria', 't', 'he', 'erb', 'h', ',', 'eesoderbur', 'esk', 'ay', 's', 'seri', 'ok', 'q', 't2', 'u', '3', 'd', 'thef', 'py', 'inthe', 'oderb', 'm', 'co', '1', 'rig', 'es', 'bo', 'igne', 'op', 'ko', 'r', 'le', '2', 'alf', 'ht', 'eries', 'l', 'lo', 'th', 'yl', 'as', 'ka', 'kayl', 'c', 'ur', 'b', 'ing', 'er', 'bu', 'ig', '7', 'eesod', 'f', 'y', 'nein', 'a', 'n', 'fig', '9', 'e', 'ylees', '?', 'x', '\n', '8', 'ne', 'igh', 'all', 'od', 'neeri', '20', 'ees', 'the', 'g', 'eri', '4', 'in', 'f-', 'al', 'j', '.', 'theh', '-', 'of', 'fal', 'i', ':', 'lin', 'erbur', 'p', 'k', 'o', 'eso', 'kayleesoderbur', 'one', 'rg', 'der', 'v', 'kayleesod', 'w', '-l', '01', 'yr'}
# splits: ['theh', 'alf', '-l', 'ing', 'bo', 'ok', 'one', 'inthe', 'fal', 'lo', 'fig', 'neeri', 'as', 'eries', 'kayleesoderbur', 'gc', 'op', 'yr', 'igh', 't2', '01', '3', 'kayleesoderbur', 'g', 'all', 'rig', 'ht', 's', 'r', 'es', 'er', 'v', 'e', 'd', '.', '\n', 'i', 's', 'b', 'n', ':', '1', '4', '9', '2', '9', '1', '3', '7', '3', '1', 'i', 's', 'b', 'n', '-', '1', '3', ':', '9', '7', '8', '-', '1', '4', '9', '2', '9', '1', '3', '7', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'e', 'd', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'er', 'v', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'e', 'd', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'rig', 'ht', '?', '\n', 'i', 'w', 'i', 's', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.', '\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.', '\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.', '\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 'v', 'e', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'e', 'd', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.', '\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.', '\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'theh', 'alf', 'of', 'i', 't', '.', '\n', 'bu', 't', 'i', 'd', 'o', '.', '\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'i', 's', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.', '\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'i', 's', 'i', 's', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 'v', 'e', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.', '\n', 'i', 'w', 'al', 'k', 'e', 'd', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.', '\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ing', 'bo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.', '\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'e', 'd', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.', '\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'e', 'd', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', 'r', 'a', 'm',  ...
# vocab: {'gb', 'gc', '49', 'gall', 'z', 'hal', '0', 'neerias', 'oo', '-ling', 'eria', 't', 'he', 'erb', 'h', ',', 'eesoderbur', 'hts', 'esk', 'ay', 'ight2', 'd.', 's', 'seri', 'erv', 'ok', 'q', 'opyr', 't2', '1i', 'thehalf', 'u', 'allrig', '013', '3', 'd', 'thef', 'py', 'inthe', 'oderb', 'is', 'm', 'co', 've', '1', 'rig', 'es', 'bo', '92', ':1', 'igne', 'kayleesoderburg', 'op', 'ko', 'r', '73', 't201', '.\n', 'le', 'kayleesoderburgc', '2', 'alf', 'ht', 'eries', 'l', 'lofig', 'inthefal', 'lo', 'res', 'th', 'yl', 'okone', 'as', 'ka', 'kayl', '91', 'c', '29', 'ur', 'b', 'ing', 'er', 'bu', 'ig', 'erieskayleesoderbur', 'aseries', '7', 'eesod', 'f', 'y', 'nein', 'a', 'n', '3kayleesoderbur', 'oneinthe', 'fig', '9', 'e', 'ylees', '?', 'x', 'right', '13', '\n', '8', 'ne', 'igh', 'all', 'book', 'od', 'neeri', '20', 'ees', 'the', 'sr', 'g', 'eri', '4', 'bn', 'in', 'f-', 'al', 'j', '.', '14', 'theh', '-', 'of', 'figneeri', 'fal', 'i', ':', 'lin', 'fallo', 'erbur', 'ed', 'p', 'k', 'o', 'eso', 'kayleesoderbur', 'ingbo', 'one', 'rg', 'der', 'yrigh', '31', '\ni', 'alf-l', 'v', 'kayleesod', 'w', '37', 'sb', 'gcop', '-l', 'n:', '01', 'eser', 'yr'}
# splits: ['thehalf', '-ling', 'book', 'oneinthe', 'fallo', 'figneeri', 'aseries', 'kayleesoderburgc', 'opyr', 'ight2', '013', 'kayleesoderburg', 'allrig', 'hts', 'res', 'erv', 'ed', '.\n', 'is', 'bn', ':1', '49', '29', '13', '73', '1', 'is', 'bn', '-', '13', ':', '9', '7', '8', '-', '14', '92', '91', '37', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'ed', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'erv', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'ed', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'right', '?', '\ni', 'w', 'is', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 've', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'ed', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'thehalf', 'of', 'i', 't', '.\n', 'bu', 't', 'i', 'd', 'o', '.\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'is', 'is', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 've', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.\n', 'i', 'w', 'al', 'k', 'ed', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ingbo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'ed', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'ed', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', 'r', 'a', 'm', 'm', 'ed', 'in', 't', 'o', 'a', 't', 'r', 'e', 'e', '.\n', 'i', 'k', 'i', 'c', 'k', 'ed', 'a', 'r', 'o', 'c', 'k', 'in', 't', 'o', 'the', 'g', 'r', 'as', 's', '.\n', 'th', 'es', 'u', 'n', 'w', 'as', 's', 't', 'a', 'r', 't', 'ing', 't', 'o', 's', 'e ...
# vocab: {'gb', 'gc', '49', 'gall', 'isbn', 'z', 'hal', '0', 'neerias', 'oo', '-ling', 'eria', 't', 'he', 'erb', 'h', ',', 'eesoderbur', 'hts', 'esk', 'ay', 'ight2', 'd.', 's', 'seri', 'erv', 'ok', 'q', 'opyr', 't2', '1i', 'thehalf', 'u', 'allrig', '013', '3', 'd', 'thef', 'py', 'inthe', 'oderb', 'is', 'm', 'co', 've', '1', 'rig', 'es', 'bo', '92', ':1', 'igne', 'kayleesoderburg', 'op', 'ko', 'r', '73', 't201', '.\n', 'le', 'kayleesoderburgc', '2', 'alf', 'ht', 'eries', 'l', 'lofig', 'inthefal', 'lo', 'res', 'th', 'yl', 'okone', 'as', 'ka', 'kayl', '91', 'c', '29', 'ur', 'b', 'ing', 'er', 'bu', 'ig', 'erieskayleesoderbur', 'aseries', '7', 'eesod', 'f', 'y', 'nein', 'a', 'n', '3kayleesoderbur', 'oneinthe', 'fig', '9', 'e', 'ylees', '?', 'x', 'right', '13', '\n', '8', 'ne', 'igh', 'all', 'book', 'od', 'neeri', '20', 'ees', 'the', 'sr', 'g', 'eri', '4', 'bn', 'in', 'f-', 'al', 'j', '.', '14', 'theh', '-', 'of', 'figneeri', 'fal', 'i', ':', 'lin', 'fallo', 'erbur', 'ed', 'p', 'k', 'o', 'eso', 'kayleesoderbur', 'ingbo', 'one', 'rg', 'der', 'yrigh', '31', '\ni', 'alf-l', 'v', 'kayleesod', 'w', '37', 'sb', 'gcop', '-l', 'n:', '01', 'eser', 'yr'}
# splits: ['thehalf', '-ling', 'book', 'oneinthe', 'fallo', 'figneeri', 'aseries', 'kayleesoderburgc', 'opyr', 'ight2', '013', 'kayleesoderburg', 'allrig', 'hts', 'res', 'erv', 'ed', '.\n', 'isbn', ':1', '49', '29', '13', '73', '1', 'isbn', '-', '13', ':', '9', '7', '8', '-', '14', '92', '91', '37', '3', '3', 'f', 'o', 'r', 'm', 'y', 'f', 'a', 'm', 'i', 'l', 'y', ',', 'w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'ed', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'f', 'o', 'r', 'm', 'y', 'd', 'r', 'e', 'a', 'm', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'erv', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'ed', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'right', '?', '\ni', 'w', 'is', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'o', 'r', 'k', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'a', 'm', 'e', '.\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 've', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'ed', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.\n', 'o', 'n', 'l', 'y', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'thehalf', 'of', 'i', 't', '.\n', 'bu', 't', 'i', 'd', 'o', '.\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'is', 'is', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'm', 'i', 'l', 'y', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 've', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.\n', 'i', 'w', 'al', 'k', 'ed', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.\n', 'm', 'y', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'm', 'y', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'i', 'l', 'le', 'd', 'w', 'i', 'th', 'm', 'y', 'w', 'r', 'i', 't', 'ingbo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.\n', 'i', 'k', 'e', 'p', 't', 'm', 'y', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'ed', 'r', 'o', 'a', 'd', ',', 'w', 'a', 't', 'c', 'h', 'ing', 'm', 'y', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'o', 'r', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'm', 'y', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'ed', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', 'r', 'a', 'm', 'm', 'ed', 'in', 't', 'o', 'a', 't', 'r', 'e', 'e', '.\n', 'i', 'k', 'i', 'c', 'k', 'ed', 'a', 'r', 'o', 'c', 'k', 'in', 't', 'o', 'the', 'g', 'r', 'as', 's', '.\n', 'th', 'es', 'u', 'n', 'w', 'as', 's', 't', 'a', 'r', 't', 'ing', 't', 'o', 's', 'e', 't',  ...
# vocab: {'gb', '33', 'figneeriaseries', 'gc', '49', 'gall', 'isbn', 'z', 'or', 'hal', '0', 'neerias', 'oo', '731', '-ling', 'yf', 'eria', 't', 'he', 'erb', 'h', ',', 'eesoderbur', 'hts', 'esk', 'ay', 'ight2', 'rm', 'd.', 'fallofigneeri', 's', 'seri', 'erv', 'ok', 'q', '3f', 'opyr', 't2', '1i', '4929', ':9', 'thehalf', 'u', 'allrig', 'erved', '1492', '013', '3', 'd', '97', 'thef', 'py', 'inthe', 'oderb', 'is', 'm', 'co', '78', 've', '1', 'rig', 'es', '013kayleesoderburg', 'bo', '92', ':1', 'igne', 'ight2013', ':149', 'kayleesoderburg', 'kayleesoderburgcopyr', 'op', '2913', 'bookoneinthe', 'ko', 'r', '73', 'fa', 't201', '.\n', 'le', 'kayleesoderburgc', '2', 'alf', 'ht', 'eries', 'l', 'lofig', '-13', 'inthefal', 'lo', 'res', 'th', 'isbn-', 'opyright2', 'isbn:1', 'yl', 'okone', 'ed.\n', '-14', 'as', 'ka', 'kayl', '91', 'c', 'thehalf-ling', 'mi', 'reserv', '29', 'ur', '13:', 'y,', 'b', 'ing', 'er', 'bu', 'ig', 'allrights', 'htsres', 'erieskayleesoderbur', 'aseries', 'kayleesoderburgallrig', '7', 'eesod', 'f', 'my', 'y', '8-', 'nein', 'a', 'n', '3kayleesoderbur', '.\nisbn', 'oneinthe', 'fig', '9', 'e', 'ylees', '?', 'aserieskayleesoderburgc', 'x', '-lingbook', 'right', '373', '13', '\n', '8', 'ne', 'igh', 'all', 'book', 'od', 'neeri', '20', 'ees', 'the', 'sr', 'g', 'eri', 'ly', '4', '1isbn', '9137', 'bn', 'in', 'f-', 'oneinthefallo', 'am', 'al', 'j', '.', '14', 'theh', '-', 'of', 'figneeri', 'fal', 'i', ':', 'lin', 'fallo', 'erbur', 'ed', 'p', ',w', 'k', 'o', 'eso', 'kayleesoderbur', 'fo', 'ingbo', 'one', 'rg', 'der', 'yrigh', '31', 'il', '\ni', 'alf-l', 'v', 'kayleesod', 'w', '37', 'sb', 'gcop', '-l', 'n:', '01', 'eser', '1373', '9291', 'yr'}
# splits: ['thehalf-ling', 'bookoneinthe', 'fallofigneeri', 'aserieskayleesoderburgc', 'opyright2', '013kayleesoderburg', 'allrights', 'reserv', 'ed.\n', 'isbn:1', '4929', '1373', '1isbn', '-13', ':9', '78', '-14', '9291', '373', '3f', 'or', 'my', 'fa', 'mi', 'ly', ',w', 'h', 'o', 'e', 'n', 'co', 'ur', 'a', 'g', 'ed', 'm', 'e', 't', 'one', 'v', 'er', 's', 't', 'op', 'fig', 'ht', 'ing', 'fo', 'rm', 'y', 'd', 'r', 'e', 'am', 's', 'c', 'h', 'a', 'p', 't', 'er', '1', 's', 'u', 'm', 'm', 'erv', 'a', 'c', 'a', 't', 'i', 'o', 'n', 's', 's', 'u', 'p', 'p', 'o', 's', 'ed', 't', 'o', 'b', 'e', 'f', 'u', 'n', ',', 'right', '?', '\ni', 'w', 'is', 'h', 'i', 'h', 'a', 'd', 'a', 'b', 'e', 't', 't', 'er', 'a', 'n', 's', 'w', 'er', 't', 'o', 'th', 'a', 't', 'q', 'u', 'es', 't', 'i', 'o', 'n', '.\n', 's', 't', 'a', 'r', 'lin', 'g', 's', ',', 'ne', 'w', 'y', 'or', 'k', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'y', 'o', 'u', 'd', 'e', 'x', 'p', 'e', 'c', 't', 'm', 'u', 'c', 'ht', 'o', 'h', 'a', 'p', 'p', 'e', 'n', '.\n', 'i', 't', 's', 'as', 'm', 'all', 'q', 'u', 'i', 'e', 't', 't', 'o', 'w', 'n', ',', 'the', 'k', 'in', 'd', 'w', 'h', 'er', 'e', 'e', 'v', 'er', 'y', 'one', 'k', 'n', 'o', 'w', 's', 'y', 'o', 'ur', 'n', 'am', 'e', '.\n', 'i', 't', 's', 'a', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'ur', 'p', 'a', 'r', 'e', 'n', 't', 's', 'w', 'o', 'u', 'l', 'd', 'n', 't', 'e', 've', 'n', 'c', 'a', 'r', 'e', 'i', 'f', 'y', 'o', 'u', 's', 't', 'ay', 'ed', 'o', 'u', 't', 'l', 'a', 't', 'e', 'b', 'i', 'k', 'ing', 'w', 'i', 'th', 'y', 'o', 'ur', 'f', 'r', 'i', 'e', 'n', 'd', 's', '.\n', 'o', 'n', 'ly', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'e', 'v', 'er', 'y', 'one', 'f', 'e', 'l', 't', 's', 'o', 's', 'a', 'f', 'e', ',', 's', 'o', 'co', 'm', 'f', 'y', '.\n', 'the', 'y', 'd', 'o', 'n', 't', 'k', 'n', 'o', 'w', 'thehalf', 'of', 'i', 't', '.\n', 'bu', 't', 'i', 'd', 'o', '.\n', 'i', 'k', 'n', 'o', 'w', 'i', 't', 'all', 'a', 'n', 'd', 's', 't', 'a', 'r', 'lin', 'g', 's', 'is', 'n', 'o', 't', 'the', 'p', 'l', 'a', 'c', 'e', 'w', 'h', 'er', 'e', 'y', 'o', 'u', 'w', 'a', 'n', 't', 't', 'o', 'b', 'e', 'a', 'f', 't', 'er', 'd', 'a', 'r', 'k', '.\n', 'the', 'o', 'n', 'l', 'yr', 'e', 'as', 'o', 'n', 'w', 'h', 'y', 'n', 'oo', 'ne', 'k', 'n', 'o', 'w', 's', 'th', 'is', 'is', 'b', 'e', 'c', 'a', 'u', 's', 'e', 'j', 'as', 'o', 'n', ',', 'e', 'mi', 'ly', ',', 's', 'e', 'th', 'a', 'n', 'd', 'i', 'h', 'a', 've', 'k', 'e', 'p', 't', 'i', 't', 'th', 'a', 't', 'w', 'ay', '.\n', 'i', 'w', 'al', 'k', 'ed', 'al', 'o', 'n', 'g', 'the', 'e', 'm', 'p', 't', 'yr', 'o', 'a', 'd', 'al', 'one', ',', 'o', 'c', 'c', 'as', 'i', 'o', 'n', 'all', 'y', 'w', 'a', 'v', 'ing', 't', 'op', 'as', 's', 'ing', 'k', 'i', 'd', 's', 'o', 'n', 'b', 'i', 'k', 'es', '.\n', 'my', 'b', 'a', 'c', 'k', 'p', 'a', 'c', 'k', 'w', 'as', 's', 'l', 'u', 'n', 'g', 'o', 'v', 'er', 'my', 's', 'h', 'o', 'u', 'l', 'der', ',', 'f', 'il', 'le', 'd', 'w', 'i', 'th', 'my', 'w', 'r', 'i', 't', 'ingbo', 'ok', 's', 'a', 'n', 'd', 's', 'k', 'e', 't', 'c', 'h', 'p', 'a', 'd', 's', '.\n', 'i', 'k', 'e', 'p', 't', 'my', 'e', 'y', 'eso', 'n', 'th', 'es', 'h', 'a', 'd', 'o', 'w', 'ed', 'r', 'o', 'a', 'd', ',w', 'a', 't', 'c', 'h', 'ing', 'my', 'e', 'v', 'er', 'y', 's', 't', 'e', 'p', '.\n', 'u', 's', 'u', 'all', 'y', 'i', 'w', 'as', 'm', 'or', 'e', 'a', 'w', 'a', 'r', 'e', 'of', 'my', 's', 'ur', 'r', 'o', 'u', 'n', 'd', 'ing', 's', ',', 'bu', 't', 't', 'od', 'ay', 'i', 'w', 'as', 't', 'i', 'r', 'ed', 'a', 'n', 'd', 'd', 'i', 'd', 'n', 't', 'c', 'a', 'r', 'e', 'i', 'f', 'i', 'r', 'am', 'm', 'ed', 'in', 't', 'o', 'a', 't', 'r', 'e', 'e', '.\n', 'i', 'k', 'i', 'c', 'k', 'ed', 'a', 'r', 'o', 'c', 'k', 'in', 't', 'o', 'the', 'g', 'r', 'as', 's', '.\n', 'th', 'es', 'u', 'n', 'w', 'as', 's', 't', 'a', 'r', 't', 'ing', 't', 'o', 's', 'e', 't', ',', 'p', 'a', 'in', 't', 'ing', 'th', 'esk', 'y', 'in', 'b', 'r', 'il', 'l', 'i', 'a', 'n', 't', 'or', 'a', 'n', 'g', 'es', 'a', 'n', 'd', 'r', 'ed', 's', '.\n', 'i', 't', 's' ...

# %%
class BPE:
    def __init__(self, vocab_size=50):
        self.vocab_size = vocab_size
        self.vocab = set()
        self.split = list()

    @staticmethod
    def __create_corpus(path: Path):
        '''Creates the first word corpus for BPE.

        Parameters:
            path[Path]: path to the txt file
        '''
        with open(path, 'r') as f:
            file = f.read()
        return re.sub(r'[^\x00-\x7F]+', '', file).split(' ')

    def __split_and_initiate(self, wordcorpus: list):
        for word in wordcorpus:
            for i, char in enumerate(word):
                self.split.append(char)
                self.vocab.add(char)
                if i < len(word) - 1:
                    self.split.append(' ')
                    self.vocab.add(' ')

    def __count(self):
        '''Creates a defaultdict which shows frequency of
        repeated elements.

        Parameters:
            placeholder
        Returns:
            splits[defaultdict]: defaultdict of frequencies
        '''
        pairs = defaultdict(int)
        splint_len = len(self.split)
        for i in range(splint_len - 1):
            if self.split[i] != ' ' and self.split[i + 1] != ' ':
                pair = f'{self.split[i]}<sp>{self.split[i+1]}'
                pairs[pair] += 1
                if len(pairs) > 50:
                    break
        return pairs

    def __add_to_vocab(self, pairs, max_freq):
        '''Adds given tokens to vocab'''
        for tup in pairs.items():
            if tup[1] == max_freq:
                self.vocab.add(tup[0].replace('<sp>', ''))

    def __merge(self, pair):
        f, s = pair.split('<sp>')
        ind = 0
        while ind < len(self.split) - 1:
            if self.split[ind] == f and self.split[ind + 1] == s:
                self.split = self.split[:ind] + [f + s] + self.split[ind + 2:]
            else:
                ind += 1
                
    def __find_best(self):
        return self.__count()

    def train(self, path, vocab_size):
        corpus = self.__create_corpus(path)
        self.__split_and_initiate(corpus)
        while len(self.vocab) < vocab_size:
            pairs = self.__find_best()
            if not pairs:
                print('No more pairs to process')
                break
            max_freq = max(pairs.values())
            highest_freq_vals = [k for k, v in pairs.items() if v == max_freq]
            self.__add_to_vocab(pairs, max_freq)
            for item in highest_freq_vals:
                self.__merge(item)

# %%
tokenizer = BPE()
tokenizer.train('toy_data/example.txt', 2000)
print(tokenizer.vocab)
# Out:
# No more pairs to process
# {'nih', 'u', 'lf', 'ew', '3if', 'dit', 'yg', 't', 'ca', 'y;i', 'sj', 'r,n', 'un', 'd,n', 'diw', 'nj', 'lo', 'tt', 'wf', 'gah', 'lt', 'mw', 'fir', 'dab', 't,w', 'md', 'pa', 'n,w', '-', 'do', 'h', 'o', 'ia', 'gal', 'fh', 'd', 'e,t', 'eik', 'mo', 'ie', 'ee', 'fl', 'f,', 'h,ir', 'og', 'lm', 'eij', 'y!', 'g!', 'oo', 'ls', 'hiw', 'saf', 's,p', 'el', ',t', ':w', 'haf', 'g,i', 'hj', '.', 'w,', 'l;i', 'r?', 'eiw', ';t', 'r.', 'eh', 'xm', 'eaq', 'e,d', 't,t', 'ed', 'mf', 'fc', 't,g', 'ub', 'hb', 'gac', 'yj', 'r,o', 'sic', 'fio', 'm.', 'rf', 's,aw', 'k', 'f.', 'iq', 'le', 'j', 'fp', 'n,l', 'ws', 'kh', 'e,w', 'ph', '.w', 'tp', 'ku', 'fs', ' ', 'so', 'hih', 's,', 'sc', ',s', 'bt', 'e,e', 'kl', 'il', 'nir', 'sf', '1', '\n', 'rn', 'sad', 'h,', 'gi', 'saw', 'hm', 'nd', 'dp', 'q', 'ik', 'dia', 't,l', ',f', 'e,b', 'gic', 'lg', 'tan', 'gak', 'ej', 'i,h', 's;w', ',n', 'rak', 'di', 'gb', 'ns', 'f', 'n,d', 'dap', 'cb', '8', 'lic', ',w', 'd,w', 'ok', 'r,f', 'ha', 'e,m', 'p,s', 'd,a', 'sis', 'dam', 'g,l', 't,ir', 'r,j', 'g,', 'su', 't2', 'nn', 'ma', 'nil', 's', 'gd', 'did', 'nac', 'hy', 'oj', 'u?', 'yl', 't,o', 'nm', 'r,t', 'y,f', 'y.', 'd?', 'nf', 'i', 'wh', 'wy', 'gk', 'mm', 'yt', 'db', 'tis', 'hah', 'nam', 'ld', 'c.', 'gl', 'df', 'l,a', 'y,s', 'fu', 'uo', 'op', 's,e', 'rv', 'naf', 'sig', 's!', 's;', 'ht', 'sih', 'n?', 'h.', 's,b', 'fm', 'sak', 'dar', 'ab', 't,ic', 'tac', 'd,iw', '3f', 'hap', 'n,j', 'hh', 'ev', 'k?', 'nh', 'ko', 'in', 'pw', 'if', 'yq', 'fo', 'ty', 'o.', 'd,s', 'wo', 'dt', 'ly', 'oit', 'o,p', 't;', 'g?', 'th', 'ig', 'yu', 'r,y', 'ip', 'tih', 'm,g', 'ear', 'wg', 'ud', ',g', 'n.', 'a', 'b', 'r,h', 'tb', 'sap', 'sie', '4', 'siw', 'kif', 'ua', 'ek', '5', ';', 'hf', 'l,h', 'sn', 'n:1', '6', 'td', 'ei', 'or', 'nc', '2iw', 'd,h', 'nik', 'eb', 'sib', 'em', 'lu', 'd,l', 'oc', 'n,iw', 'h,i', 'y,i', 'ui', 'ea', 'es', 'fih', 'tat', 'taq', 'r,s', 'l!', 'kf', 'rj', 'n', 'oat', 'fiw', 'das', 'ff', 'w', 'u,j', 'ral', 'fd', 'tw', ',j', 'n,n', 'dic', 'oic', 'ro', 'fe', 'of', 'oi', 'tm', 'u.', 'yh', 'dq', 'ms', 'yiw', 'wd', 'o?', 't.', 'ts', 'ep', 'np', 'er', 'ga', 'dg', 'd,e', 'sa', 'ow', 'c', 'eis', 'yk', 'hat', 'r,a', 's,o', 'kr', 'tg', 'uj', 'yv', 't,d', 'sy', 'dy', 'e', 'l,i', 'ni', ';w', 'st', 'ric', 'y?', 'gm', 'ic', 'si', 'wk', 'wb', 'd:w', 'z.', 'gw', 'n,s', 'gu', ':9', 'e.', 'sab', 'fav', 'dw', ',a', 'n,r', 'ks', 'bi', 'yc', 'km', 'sv', 'y', 'nw', 'r,w', 'sl', 'dal', 'rk', 'e!', 'l,', 'to', '2w', 't,p', 'yaj', 'pe', 'n,', 'ug', 'du', 'r,', 'en', 'd,b', 'iw', 'fi', 'n:', 'eil', 'd,p', 'uc', 'rb', 'nk', 'gp', 'p,t', '?', 'ein', 'gr', 't1', 'ry', 'wak', 's,a', 'ta', 'e:w', 'ef', 'tf', 'tit', 'tu', 'mc', 'ir', 'lb', 'faw', 'kg', 'rg', '3:9', 'hw', 'l,ig', 'i.', 'oir', 'eac', 'dk', 'k,', 'm,is', '2', 'giw', 'ke', 'id', 'gt', 'hg', 'sas', 'wm', 'et', '!', 'ra', 'fw', 'yah', 'u,t', 'y,', 'sm', 'nb', 'yw', 'h,b', 'f,b', 'lal', 'mh', 'd,t', '.s', 'hu', 'nah', 'l', 'sh', 'yd', '1s', 'kp', 'sal', 'ho', ',r', 'rw', 'gs', 'rh', 'no', ';i', 'l,w', 'd,f', 'ym', 'g,a', 's,w', 'l,y', 'ti', 'ft', 'io', 'ut', 'lp', 'n,c', ',h', 'ka', 'sit', 'us', 'h,t', 'tid', 'kw', 'i,', 'af', 'na', 'ng', 'g,w', 'y,w', 'ne', 'nt', 'r2w', 'de', 'fac', '7', 'gn', 't,', 'it', '6.', 'e,f', 't?', 'h,y', 'rp', 'maw', 'l?', 'oy', 't,f', 'ob', 'lr', 'hi', 't,m', 'sb', 'eih', 'm,l', 'oh', 'w,t', 'sir', 'sw', 'hr', 'y,id', 'sim', 'wc', 'g,b', 'mi', 'go', 'g,c', 'kd', 'ss', 'oa', 'tv', 'cf', 'wj', 'e,', 's.', 'hc', 't,u', 'pt', 'fas', 'd.', ',ih', 'naw', 'nas', 'li', '0', 'rs', 'ec', 'sg', 'rd', 'n,h', 'wa', 'he', 'lh', 'r!', 's,m', 'riw', 'bm', 'se', 'hs', 'rr', 'kab', 'h,a', 'nib', 'hp', 's?', 'fn', 'ol', '3k', 'ds', 'ny', ',p', 'eo', 'kb', 'y,j', 'lv', 'dat', 's,n', 'h,w', '3', 'dif', 'dc', 'g.', 'gh', 'sr', 'w,a', 'r', 'ou', 'uw', 'kt', 'e,y', ',', 'nab', 'e,a', 'ih', 'r,b', 'd,r', 'al', 'lam', 'as', 'ys', 'eam', 'h?', 'yo', 'ij', 'hab', 'fy', 'ov', 'tic', 'yi', 'm,', 'wi', 'e,c', 'nu', 'dh', 'r2', 'eu', 'im', 'cab', 'os', 'pr', 'm', 'yr', 'yf', 'di.', ',i', 'aw', 'uh', 'tas', 'tap' ...
